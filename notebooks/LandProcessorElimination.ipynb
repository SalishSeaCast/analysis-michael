# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import netCDF4 as nc
f1 = nc.Dataset('/data/mdunphy/Orcinus/Test6770-4x9/SalishSea_1d_20150612_20150612_grid_T.nc', 'r')
f2 = nc.Dataset('/data/mdunphy/Orcinus/Test6770-8x18/SalishSea_1d_20150612_20150612_grid_T.nc', 'r')
f3 = nc.Dataset('/data/mdunphy/Orcinus/Test6770-11x25/SalishSea_1d_20150612_20150612_grid_T.nc', 'r')

# %%
plt.subplot(1,3,1); t1 = f1.variables['votemper'][-1,0,...]; plt.imshow(t1)
plt.subplot(1,3,2); t2 = f2.variables['votemper'][-1,0,...]; plt.imshow(t2)
plt.subplot(1,3,3); t3 = f3.variables['votemper'][-1,0,...]; plt.imshow(t3)
# Out:
# <img src="data:image/png;base64,...">

# %%
x3 = f3.variables['nav_lon'][:]; y3 = f3.variables['nav_lat'][:]
plt.pcolormesh(x3,y3,t3)
plt.gca().set_xlim([-126.5, -120])
plt.gca().set_ylim([46, 51.5])
# Out:
# <img src="data:image/png;base64,...">
# (46, 51.5)

# %%
fc = nc.Dataset('/home/mdunphy/MEOPAR/NEMO-forcing/grid/coordinates_seagrid_SalishSea.nc', 'r')
x = fc.variables['nav_lon'][:]; y = fc.variables['nav_lat'][:]
plt.pcolormesh(x,y,t3)
plt.gca().set_xlim([-126.5, -120])
plt.gca().set_ylim([46, 51.5])
# Out:
# <img src="data:image/png;base64,...">
# (46, 51.5)
